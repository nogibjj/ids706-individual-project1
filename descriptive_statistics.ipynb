# %% [markdown]
# ## Descriptive Statistics using Shared Library

# %%
from lib import generate_data, describe_with_pandas, generate_scatter_plot

# %%
df = generate_data("iris.csv")

# %%
pandas_stats = describe_with_pandas(df)
print("Descriptive statistics using Pandas:")
print(pandas_stats)
# Out:
# Descriptive statistics using Pandas:
#              Id  SepalLengthCm
# count  7.000000       7.000000
# mean   4.000000       4.900000
# std    2.160247       0.294392
# min    1.000000       4.600000
# 25%    2.500000       4.650000
# 50%    4.000000       4.900000
# 75%    5.500000       5.050000
# max    7.000000       5.400000

# %%
# Generate scatter plot 
generate_scatter_plot(df, "Id", "SepalLengthCm")
